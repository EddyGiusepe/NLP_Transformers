# %% [markdown]
# <h1 align='center'>NER de um artigo de Notícias</h1>

# %% [markdown]
# Data Scientist.: Dr.Eddy Giusepe Chirinos Isidro

# %% [markdown]
# Vamos extrair dados de um `artigo de notícias na web` e fazer `NER` nos dados de texto coletados a partir daí.
#
# Usaremos o `Beautiful Soup` para fins de `web scraping`.

# %%
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# A seguir, usaremos a [URL](https://www.zeebiz.com/markets/currency/news-cryptocurrency-news-today-june-12-bitcoin-dogecoin-shiba-inu-and-other-top-coins-prices-and-all-latest-updates-158490) do artigo de notícias.

# %%
URL = 'https://www.zeebiz.com/markets/currency/news-cryptocurrency-news-today-june-12-bitcoin-dogecoin-shiba-inu-and-other-top-coins-prices-and-all-latest-updates-158490'

# %%
html_content = requests.get(URL).text

# %%
soup = BeautifulSoup(html_content, 'lxml')

# %%
body=soup.body.text

# %%
body
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n \n\nहिंदी में पढ़ें \xa0\n\n\n\n\n\n\n\n\n\n\n\n\nLive TV\n Live TV\n\n\n\n\n\n\nHome\n\n\nMarkets\n\nStocks\nGlobal Markets\nIPO\nCompanies\nCurrency\nCommodities\n\n\n\n\nPersonal Finance\n\nIncome tax\nGST\nEPFO\nPost Office\nBanking\nInvestment\nMutual Funds\nInsurance\n\n\n\nMy Money\n\n\n\nCalculators\n\nIncome Tax Calculator\nHome Loan/EMI Calculator\nMutual Fund Returns Calculator\nPersonal Loan Calculator\nCar Loan Calculator\nSIP calculator\nLumpsum Calculator\nSWP Calculator\n\n\n\n\nVideos\n\nM Se Market\nJeb Zindagi Zaroorat\nLight Camera Stocks\nTech Takes\nBig Bulls Ka Nishana\nPaisa Wasool\nCommodity Ke MrityunjayMantra\nThe Right Property Show\n\n\n\n\nEconomy & Infra\n\nPolicy & Initiatives\nAgriculture\nTelecom\nAviation\nRailways\nRetail\nRoadways\nWorld Economy\n\n\n\n\nExclusive\n\nWealth Guide\nInterviews\n\n\n\nAuto\n\nCars\nBikes\nElectric Vehicle\nCommercial Vehicles\n\n\n\n\nTech\n\nMobiles\nGadgets\nReviews
# ...

# %%
# Vamos salvar a string (body) para um arquivo .txt
with open('texto_salvo.txt', 'w') as text_file:
    text_file.write(body)

# %% [markdown]
# Agora, usamos `regex` para limpar o texto.

# %%
body= body.replace('\n', ' ')
body= body.replace('>>', '')
body= body.replace('\xa0', '')

# %% [markdown]
# Vamos agora dar uma olhada no texto.

# %%
body
# Out:
# '                            हिंदी में पढ़ें              Live TV  Live TV       Home   Markets  Stocks Global Markets IPO Companies Currency Commodities     Personal Finance  Income tax GST EPFO Post Office Banking Investment Mutual Funds Insurance    My Money    Calculators  Income Tax Calculator Home Loan/EMI Calculator Mutual Fund Returns Calculator Personal Loan Calculator Car Loan Calculator SIP calculator Lumpsum Calculator SWP Calculator     Videos  M Se Market Jeb Zindagi Zaroorat Light Camera Stocks Tech Takes Big Bulls Ka Nishana Paisa Wasool Commodity Ke MrityunjayMantra The Right Property Show     Economy & Infra  Policy & Initiatives Agriculture Telecom Aviation Railways Retail Roadways World Economy     Exclusive  Wealth Guide Interviews    Auto  Cars Bikes Electric Vehicle Commercial Vehicles     Tech  Mobiles Gadgets Reviews Tips and Tricks Apps      Start ups  Funding  Appointments     Real Estate  Home Buyers  Builders   Axis MF   Trending  Entertainment Politics Li
# ...

# %% [markdown]
# Agora, vamos prosseguir com o `Reconhecimento de Entidade Nomeada` (NER):

# %%
import spacy
from spacy import displacy

# https://spacy.io/models/en#en_core_web_sm-labels
NER = spacy.load("en_core_web_sm")

# %%
text= NER(body)

displacy.render(text, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                            हिंदी में पढ़ें              Live TV  Live TV       Home   Markets  Stocks Global Markets IPO Companies Currency Commodities     Personal Finance  Income tax GST EPFO Post Office Banking Investment Mutual Funds Insurance    My Money    Calculators  Income Tax Calculator Home Loan/EMI Calculator Mutual Fund Returns Calculator Personal Loan Calculator Car Loan Calculator SIP calculator
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lumpsum Calculator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  SWP Calculator     Videos  M Se Market
# ...
